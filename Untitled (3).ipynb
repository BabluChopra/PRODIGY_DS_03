# %% [markdown]
# **Bank Term Deposit Prediction**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, ConfusionMatrixDisplay

# %%
#Loading data
bank = pd.read_csv("bank.csv")

# %%
bank.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
bank.shape
# Out:
# (11162, 17)

# %% [markdown]
# **Data Pre-Processing**

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  object
#  3   education  11162 non-null  object
#  4   default    11162 non-null  object
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  object
#  7   loan       11162 non-null  object
#  8   contact    11162 non-null  object
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  object
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11162 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %%
#Statistical Analysis
bank.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean      41.231948   1528.538524     15.658036    371.993818      2.508421
# std       11.913369   3225.413326      8.420740    347.128386      2.722077
# min       18.000000  -6847.000000      1.000000      2.000000      1.000000
# 25%       32.000000    122.000000      8.000000    138.000000      1.000000
# 50%       39.000000    550.000000     15.000000    255.000000      2.000000
# 75%       49.000000   1708.000000     22.000000    496.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     63.000000
#
#               pdays      previous
# count  11162.000000  11162.000000
# mean      51.330407      0.832557
# std      108.758282      2.292007
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       20.750000      1.000000
# max      854.000000     58.000000

# %%
bank.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# deposit      0
# dtype: int64

# %%
bank.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Exploratory Data Analysis**

# %% [markdown]
# **Age Distribution**

# %%
sns.histplot(x="age", data=bank, kde=True, hue="deposit")
plt.title("Age Distribution and Deposits\n")
plt.show()

# %% [markdown]
# Maximum clients are between the age 30-40 and majority clients subscribing to term Deposite also fall between these age groups.

# %% [markdown]
# **Distribution of Occupation**

# %%
plt.figure(figsize=(15,4))
sns.countplot(x="job", data=bank, hue="deposit")
plt.title("Occupation Distribution and Deposits\n")
plt.show()

# %% [markdown]
# Majority of clients have occupation "Management","Blue-collar" or "technician" and maximum clients subscribing to Term Deposite also are from these occupation.

# %% [markdown]
# **Distribution of marital Status**

# %%
plt.figure(figsize=(7,3))
sns.countplot(x="marital", data=bank, hue="deposit")
plt.title("Marital Status and Deposits\n")
plt.show()

# %% [markdown]
# Clients are mostly married

# %% [markdown]
# **Distribution of Education Status**

# %%
plt.figure(figsize=(12,4))
sns.countplot(x="education",data=bank,hue="deposit")
plt.title("Education Status and Deposit\n")
plt.show()

# %% [markdown]
# Most of the clients have  Secondary Education

# %% [markdown]
# **Credit Defaults - any?**

# %%
bank.default.value_counts()
# Out:
# default
# no     10994
# yes      168
# Name: count, dtype: int64

# %% [markdown]
# 168 clients have credit default

# %% [markdown]
# **Distribution of Housing Loan**

# %%
plt.figure(figsize=(6,3.5))
sns.countplot(x="housing",data=bank,hue="deposit")
plt.title("Housing Loan Distribution and Deposits\n")
plt.show()

# %% [markdown]
# **Distribution of Personal Loan**

# %%
plt.figure(figsize=(6,3.5))
sns.countplot(x="loan",data= bank,hue="deposit")
plt.title("Personal Loan Distribution and Deposits\n")
plt.show()

# %% [markdown]
# Most of the Clients subscribing to Term Deposits don't have personal Loan

# %% [markdown]
# **Distribution of Outcome(Term Deposits)**

# %%
#Count of Outcome
bank.deposit.value_counts()
keys = bank.deposit.value_counts().index
data = bank.deposit.value_counts().values
plt.figure(figsize=(6,3.5))
explode = [0,0.1]
plt.pie(data, labels=keys,explode=explode,autopct='%0f%%')
plt.show()

# %% [markdown]
# 47.39% of clients have subscribed to Term Deposit

# %% [markdown]
# ***Let us now prepare our data for Model Building***

# %% [markdown]
# **Label Encoding Categorical Features**

# %%
cols = bank.select_dtypes("object").columns
cols
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'deposit'],
#       dtype='object')

# %%
le = LabelEncoder()
bank[cols] = bank[cols].apply(le.fit_transform)

# %%
bank.head(3)
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   59    0        1          1        0     2343        1     0        2
# 1   56    0        1          1        0       45        0     0        2
# 2   41    9        1          1        0     1270        1     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome  deposit
# 0    5      8      1042         1     -1         0         3        1
# 1    5      8      1467         1     -1         0         3        1
# 2    5      8      1389         1     -1         0         3        1

# %% [markdown]
# **Correlation Analysis using Heatmap**

# %%
plt.figure(figsize=(23,10))
sns.heatmap(bank.corr(), cmap='bwr', annot=True)
plt.show()

# %% [markdown]
# **Standardisation**

# %%
#Splitting input and output
X=bank.drop("deposit", axis=1)
y = bank.deposit

# %%
scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns = X.columns)

# %% [markdown]
# **Model Building - Decision Tree Classifier**

# %%
#Train-text split
train_X, test_X, train_y, test_y = train_test_split(X_scaled, y,test_size=0.3)

# %%
decision_tree = DecisionTreeClassifier()
decision_tree.fit(train_X,train_y)
# Out:
# DecisionTreeClassifier()

# %%
print('Train Score: {}'.format(decision_tree.score(train_X, train_y)))
print('Test Score: {}'.format(decision_tree.score(test_X, test_y)))
# Out:
# Train Score: 1.0
# Test Score: 0.7667960585249328

# %%
cross_val_score(decision_tree, train_X, train_y, cv=5).mean()
# Out:
# 0.7671820254394394

# %%
ypred = decision_tree.predict(test_X)
print(classification_report(test_y,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.79      0.78      1744
#            1       0.76      0.74      0.75      1605
#
#     accuracy                           0.77      3349
#    macro avg       0.77      0.77      0.77      3349
# weighted avg       0.77      0.77      0.77      3349

# %% [markdown]
# **Hyperparameter tunning**

# %%
# Applying Grid search cv to find best estimaters to improve model performance

param_grid = {
    'max_depth': [3,5,7,10,None],
    'criterion': ['gini', 'entropy'],
    'min_samples_leaf': [3,5,7,9,10,20]
}

# %%
gscv = GridSearchCV(decision_tree, param_grid, cv=5, verbose=1)
gscv.fit(train_X, train_y)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 7, 10, None],
#                          'min_samples_leaf': [3, 5, 7, 9, 10, 20]},
#              verbose=1)

# %%
gscv.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 20}

# %%
gscv.best_estimator_
# Out:
# DecisionTreeClassifier(min_samples_leaf=20)

# %%
cross_val_score(gscv.best_estimator_, train_X, train_y, cv=5).mean()
# Out:
# 0.8218348771158913

# %%
clf = DecisionTreeClassifier(criterion='gini', max_depth=5, min_samples_leaf=3)
clf.fit(train_X, train_y)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=3)

# %%
print('Train Score: {}'.format(clf.score(train_X, train_y)))
print('Test Score: {}'.format(clf.score(test_X, test_y)))
# Out:
# Train Score: 0.8078842954050941
# Test Score: 0.7882950134368468

# %%
pred_y = clf.predict(test_X)

# %%
#Confusion Matrix

cm = confusion_matrix(pred_y, test_y)
ConfusionMatrixDisplay(cm, display_labels=clf.classes_).plot()
plt.show()

# %%
#Classification Report

print(classification_report(pred_y, test_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.84      0.78      1531
#            1       0.85      0.75      0.79      1818
#
#     accuracy                           0.79      3349
#    macro avg       0.79      0.79      0.79      3349
# weighted avg       0.80      0.79      0.79      3349

# %%
#Accuracy score
accuracy = accuracy_score(test_y,pred_y)
print("Test Accuracy of Decision Tree Classifier:{}".format(accuracy*100))
# Out:
# Test Accuracy of Decision Tree Classifier:78.82950134368468

# %%
#Cross validation Score
Cross_val = cross_val_score(clf, test_X, test_y, cv=5).mean()
print("Cross-validation accuracy scores Decision Tree : ", Cross_val*100)
# Out:
# Cross-validation accuracy scores Decision Tree :  79.75467951721214

# %% [markdown]
# **Visualizing the Tree**

# %%
from sklearn import tree
fig = plt.figure(figsize=(25,20))
t=tree.plot_tree(clf, filled=True, feature_names = X.columns)
